# %%
# NSEPY is no longer available after April 2023 so download the data from https://github.com/NSEDownload/NSEDownload

# %%
#!git clone https://github.com/NSEDownload/NSEDownload
#!pip3 install NSEDownload/dist/*
# Out:
# Cloning into 'NSEDownload'...
# remote: Enumerating objects: 1223, done.
# remote: Counting objects: 100% (490/490), done.
# remote: Compressing objects: 100% (269/269), done.
# remote: Total 1223 (delta 223), reused 429 (delta 186), pack-reused 733 (from 1)
# Receiving objects: 100% (1223/1223), 1.59 MiB | 2.57 MiB/s, done.
# Resolving deltas: 100% (612/612), done.
# Processing ./NSEDownload/dist/NSEDownload-5.0.6.tar.gz
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for NSEDownload: filename=NSEDownload-5.0.6-py3-none-any.whl size=5035 sha256=675c2f977643816e441b37c6c7b98094793761984edd2241a1189595c5f6157f
#   Stored in directory: /Users/subhaarunpandian/Library/Caches/pip/wheels/f5/c8/39/81a2dc39d35412f432ff286386509b7934a966124765cbe528
# ...
#   Created wheel for timedelta: filename=timedelta-2020.12.3-py3-none-any.whl size=1556 sha256=d1e50937261f5c0bdc13acbe4dbccbf4b1bb233d164c8c3842a3e4e21f6c09a5
# ...

# %%
from Descriptive import Descriptive

# %%
des = Descriptive()

# %%
from NSEDownload import stocks
from datetime import datetime
stk_data = stocks.get_data(stock_symbol="TATACOFFEE", start_date='1-1-2023', end_date='1-1-2024')

# %%
stk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277 entries, 2022-11-27T18:30:00.000Z to 2023-12-31T18:30:00.000Z
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 277 non-null    object
#  1   Series                 277 non-null    object
#  2   High Price             277 non-null    float64
#  3   Low Price              277 non-null    float64
#  4   Open Price             277 non-null    float64
#  5   Close Price            277 non-null    float64
#  6   Last Price             277 non-null    float64
#  7   Prev Close Price       277 non-null    float64
#  8   Total Traded Quantity  277 non-null    int64
#  9   Total Traded Value     277 non-null    float64
#  10  52 Week High Price     277 non-null    float64
#  11  52 Week Low Price      277 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 28.1+ KB

# %%
stk_data
# Out:
#                               Symbol  ... 52 Week Low Price
# Date                                  ...
# 2022-11-27T18:30:00.000Z  TATACOFFEE  ...            181.65
# 2022-11-28T18:30:00.000Z  TATACOFFEE  ...            181.65
# 2022-11-29T18:30:00.000Z  TATACOFFEE  ...            181.65
# 2022-11-30T18:30:00.000Z  TATACOFFEE  ...            181.65
# 2022-12-01T18:30:00.000Z  TATACOFFEE  ...            181.65
# ...                              ...  ...               ...
# 2023-12-25T18:30:00.000Z  TATACOFFEE  ...            198.85
# 2023-12-26T18:30:00.000Z  TATACOFFEE  ...            198.85
# 2023-12-27T18:30:00.000Z  TATACOFFEE  ...            198.85
# 2023-12-28T18:30:00.000Z  TATACOFFEE  ...            198.85
# 2023-12-31T18:30:00.000Z  TATACOFFEE  ...            198.85
#
# [277 rows x 12 columns]

# %%
dataset=stk_data
quan,qual=des.segreQuanQual(dataset)
# Out:
# The Quantitative Data: ['High Price', 'Low Price', 'Open Price', 'Close Price', 'Last Price', 'Prev Close Price', 'Total Traded Quantity', 'Total Traded Value', '52 Week High Price', '52 Week Low Price']
# The Qualtitative Data ['Symbol', 'Series']

# %%
des_data=des.descriptive_Analysis(dataset,quan)
# Out:
# /Users/subhaarunpandian/Library/Mobile Documents/com~apple~Pages/Documents/Datascience/hope_ai_notes/time_series_analysis/time_series_stock_market_analysis/Descriptive.py:24: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
des_data
# Out:
#                High Price   Low Price  ... 52 Week High Price 52 Week Low Price
# Null_count              0           0  ...                  0                 0
# NonNull_count         277         277  ...                277               277
# Total_Count           277         277  ...                277               277
# Mean           241.766245  237.176534  ...          260.24278        191.695848
# Median              242.9       236.5  ...              254.4             191.2
# Mode                212.0       204.1  ...              251.7            198.85
# Std             25.749438   25.097013  ...          12.967373          7.171113
# Min                 202.8      198.85  ...              251.7            181.65
# Q1:25%              218.8       214.8  ...              251.7            182.15
# Q2:50%              242.9       236.5  ...              254.4             191.2
# Q3:75%              259.0       253.1  ...              268.9            198.85
# ...

# %%
des_data["Low Price"]
# Out:
# Null_count                0
# NonNull_count           277
# Total_Count             277
# Mean             237.176534
# Median                236.5
# Mode                  204.1
# Std               25.097013
# Min                  198.85
# Q1:25%                214.8
# Q2:50%                236.5
# Q3:75%                253.1
# Q4:100%              319.35
# IQR                    38.3
# 1.5Rule               57.45
# Lesser               157.35
# Greater              310.55
# Name: Low Price, dtype: object

# %%
des_data["High Price"]
# Out:
# Null_count                0
# NonNull_count           277
# Total_Count             277
# Mean             241.766245
# Median                242.9
# Mode                  212.0
# Std               25.749438
# Min                   202.8
# Q1:25%                218.8
# Q2:50%                242.9
# Q3:75%                259.0
# Q4:100%              324.75
# IQR                    40.2
# 1.5Rule                60.3
# Lesser                158.5
# Greater               319.3
# Name: High Price, dtype: object

# %%
import numpy as np

# %%
np.percentile(dataset["Low Price"],99) ## 99% of low price data within the value 301.3
# Out:
# 301.37800000000004

# %%
np.percentile(dataset["High Price"],99)
# Out:
# 305.78200000000004

# %%
#!pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["Low Price"], 290,300) # 1% of data are in between 290 and 300
# Out:
# Mean=237.177, Standard Deviation=25.097
# The area between range(290,300):0.012029744372607632
# /var/folders/52/3smrrwzs1674_yymbpt0326h0000gn/T/ipykernel_1171/2842244316.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# 0.012029744372607632

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["Low Price"])
# Out:
# /var/folders/52/3smrrwzs1674_yymbpt0326h0000gn/T/ipykernel_1171/3623969288.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %%
def freqTable(columnName,dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable("Low Price",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           217.00          3      1.083032    1.083032
# 1           204.10          3      1.083032    2.166065
# 2           245.00          2      0.722022    2.888087
# 3           243.50          2      0.722022    3.610108
# 4           268.30          2      0.722022    4.332130
# ..             ...        ...           ...         ...
# 235         218.50          1      0.361011   98.555957
# 236         219.70          1      0.361011   98.916968
# 237         223.90          1      0.361011   99.277978
# 238         222.80          1      0.361011   99.638989
# 239         319.35          1      0.361011  100.000000
#
# [240 rows x 4 columns]

# %%
freqTable("High Price",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           232.45          3      1.083032    1.083032
# 1           214.00          3      1.083032    2.166065
# 2           212.00          3      1.083032    3.249097
# 3           204.40          2      0.722022    3.971119
# 4           270.95          2      0.722022    4.693141
# ..             ...        ...           ...         ...
# 240         228.50          1      0.361011   98.555957
# 241         230.30          1      0.361011   98.916968
# 242         230.95          1      0.361011   99.277978
# 243         227.85          1      0.361011   99.638989
# 244         324.75          1      0.361011  100.000000
#
# [245 rows x 4 columns]

# %%
fh=freqTable("High Price",dataset)

# %%
fh
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           232.45          3      1.083032    1.083032
# 1           214.00          3      1.083032    2.166065
# 2           212.00          3      1.083032    3.249097
# 3           204.40          2      0.722022    3.971119
# 4           270.95          2      0.722022    4.693141
# ..             ...        ...           ...         ...
# 240         228.50          1      0.361011   98.555957
# 241         230.30          1      0.361011   98.916968
# 242         230.95          1      0.361011   99.277978
# 243         227.85          1      0.361011   99.638989
# 244         324.75          1      0.361011  100.000000
#
# [245 rows x 4 columns]

# %%
result = fh[fh["Frequency"] ==2]["Unique_Values"].sort_values(ascending=False)

# %%
result
# Out:
# 28    285.50
# 22    272.60
# 4     270.95
# 9     261.60
# 11    258.90
# 14    256.75
# 19    254.40
# 20    251.65
# 21    250.00
# 23    249.05
# 18    248.15
# 17    246.90
# 24    233.75
# 16    231.50
# 27    229.65
# 25    229.30
# 26    220.75
# 12    218.80
# 15    217.95
# 5     212.50
# 6     210.70
# 13    210.50
# 8     209.45
# 7     209.00
# 3     204.40
# 10    204.30
# Name: Unique_Values, dtype: float64
